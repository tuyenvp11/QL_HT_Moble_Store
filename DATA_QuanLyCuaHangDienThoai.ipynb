-- %% [markdown]
-- # [dbo].[ChiTietDonDatHang]

-- %%
USE [QuanLyCuaHangBanDienThoai]
GO

-- %%
/****** Object:  Table [dbo].[ChiTietDonDatHang]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ChiTietDonDatHang](
	[ChiTietDonDatHangId] [int] IDENTITY(1,1) NOT NULL,
	[DonDatHangId] [int] NULL,
	[SanPhamId] [int] NULL,
	[GiaBan] [float] NULL,
	[ThanhTien] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[ChiTietDonDatHangId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DoanhThu]

-- %%
/****** Object:  Table [dbo].[DoanhThu]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DoanhThu](
	[DoanhThuId] [int] IDENTITY(1,1) NOT NULL,
	[HoaDonId] [int] NULL,
	[Ngay] [date] NULL,
	[TongTien] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[DoanhThuId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DonDatHang]

-- %%
/****** Object:  Table [dbo].[DonDatHang]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DonDatHang](
	[DonDatHangId] [int] IDENTITY(1,1) NOT NULL,
	[NgayDat] [date] NULL,
	[TongGiaTriDonHang] [float] NULL,
	[KhachHangId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[DonDatHangId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HoaDon]

-- %%
/****** Object:  Table [dbo].[HoaDon]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HoaDon](
	[HoaDonId] [int] IDENTITY(1,1) NOT NULL,
	[SanPhamId] [int] NULL,
	[KhachHangId] [int] NULL,
	[SoLuong] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[HoaDonId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KhachHang]

-- %%
/****** Object:  Table [dbo].[KhachHang]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KhachHang](
	[KhachHangId] [int] IDENTITY(1,1) NOT NULL,
	[HoTen] [nvarchar](50) NULL,
	[DiaChi] [nvarchar](50) NULL,
	[SDT] [int] NULL,
	[Email] [nvarchar](40) NULL,
PRIMARY KEY CLUSTERED 
(
	[KhachHangId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LoaiSanPham]

-- %%
/****** Object:  Table [dbo].[LoaiSanPham]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LoaiSanPham](
	[LoaiSanPhamId] [int] IDENTITY(1,1) NOT NULL,
	[TenLoai] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[LoaiSanPhamId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NhaSanXuat]

-- %%
/****** Object:  Table [dbo].[NhaSanXuat]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NhaSanXuat](
	[NhaSanXuatId] [int] IDENTITY(1,1) NOT NULL,
	[TenNhaSanXuat] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[NhaSanXuatId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SanPham]

-- %%
/****** Object:  Table [dbo].[SanPham]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SanPham](
	[SanPhamId] [int] IDENTITY(1,1) NOT NULL,
	[LoaiSanPhamId] [int] NULL,
	[TenSP] [nvarchar](50) NULL,
	[NhaSanXuatId] [int] NULL,
	[SoLuong] [int] NULL,
	[GiaSP] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[SanPhamId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaiKhoan]

-- %%
/****** Object:  Table [dbo].[TaiKhoan]    Script Date: 03/10/2023 9:24:17 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaiKhoan](
	[TaiKhoanId] [int] IDENTITY(1,1) NOT NULL,
	[Usename] [nvarchar](20) NULL,
	[Password] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[TaiKhoanId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__ChiTietDo__DonDa__5812160E]

-- %%
ALTER TABLE [dbo].[ChiTietDonDatHang]  WITH CHECK ADD FOREIGN KEY([DonDatHangId])
REFERENCES [dbo].[DonDatHang] ([DonDatHangId])
GO

-- %% [markdown]
-- # [FK__ChiTietDo__SanPh__59063A47]

-- %%
ALTER TABLE [dbo].[ChiTietDonDatHang]  WITH CHECK ADD FOREIGN KEY([SanPhamId])
REFERENCES [dbo].[SanPham] ([SanPhamId])
GO

-- %% [markdown]
-- # [FK__DoanhThu__HoaDon__5EBF139D]

-- %%
ALTER TABLE [dbo].[DoanhThu]  WITH CHECK ADD FOREIGN KEY([HoaDonId])
REFERENCES [dbo].[HoaDon] ([HoaDonId])
GO

-- %% [markdown]
-- # [FK__DonDatHan__Khach__5535A963]

-- %%
ALTER TABLE [dbo].[DonDatHang]  WITH CHECK ADD FOREIGN KEY([KhachHangId])
REFERENCES [dbo].[KhachHang] ([KhachHangId])
GO

-- %% [markdown]
-- # [FK__HoaDon__KhachHan__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[HoaDon]  WITH CHECK ADD FOREIGN KEY([KhachHangId])
REFERENCES [dbo].[KhachHang] ([KhachHangId])
GO

-- %% [markdown]
-- # [FK__SanPham__LoaiSan__4D94879B]

-- %%
ALTER TABLE [dbo].[SanPham]  WITH CHECK ADD FOREIGN KEY([LoaiSanPhamId])
REFERENCES [dbo].[LoaiSanPham] ([LoaiSanPhamId])
GO

-- %% [markdown]
-- # [FK__SanPham__NhaSanX__4E88ABD4]

-- %%
ALTER TABLE [dbo].[SanPham]  WITH CHECK ADD FOREIGN KEY([NhaSanXuatId])
REFERENCES [dbo].[NhaSanXuat] ([NhaSanXuatId])
GO
